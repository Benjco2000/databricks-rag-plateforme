# %%
# Vérifie que streamlit est accessible depuis le workspace
import subprocess
result = subprocess.run(["pip", "show", "streamlit"], capture_output=True, text=True)
print("resulte : ", result.stdout)
